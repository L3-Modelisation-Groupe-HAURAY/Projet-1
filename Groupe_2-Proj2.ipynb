# %%
a=1

# %%
print('a')
# Out:
# a

# %%
import numpy as np

# %%
A=np.array([[1,2],[3,4]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B=A- np.eye(2)

# %%
B
# Out:
# array([[0., 2.],
#        [3., 3.]])
